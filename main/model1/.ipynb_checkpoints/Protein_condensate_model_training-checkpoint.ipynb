# %% [markdown]
# # Import all the packages used

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from tensorflow.data import Dataset
import vampnet

import psutil
import gc

print(tf.__version__)
from vampnet import data_generator as vamp_data_generator
from tensorflow.contrib.keras.api.keras.models import Model
from tensorflow.contrib.keras.api.keras.layers import Dense, Activation, Flatten, Input, BatchNormalization, concatenate
from tensorflow.contrib.keras.api.keras.optimizers import Adam

import matplotlib.gridspec as gridspec
from tensorflow.contrib.keras.api.keras.backend import clear_session

import psutil

gc.enable()
# Out:
# 1.15.0

# %%
! free -g
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:              15           1           0           0          13          13
# Swap:              0           0           0

# %% [markdown]
# # Define Hyperparameters

# %%
# Tau, how much is the timeshift of the two datasets
tau = 1

# Batch size for Stochastic Gradient descent
batch_size = 1000 #1000

# Which trajectory points percentage is used as training
train_ratio = 0.9

# How many hidden layers the network has
network_depth = 5

# Width of every layer
layer_width = 250 #250 for E10, 5000 for P10

layer_width_factor = 3/4

# Learning rate used for the ADAM optimizer
learning_rate = 1e-4

# How many output states the network has
output_size = 2

# Iteration over the training set in the fitting process
nb_epoch = 300 #10

epsilon = 1e-5

dump_period=1000
picoseconds_per_step = 0.01  * dump_period # ps


model_name = str(output_size) + "_states_" + "E10_peptides_input_"

# %% [markdown]
# # Get train data

# %%
path_to_raw_coords = "../../hoomd/test-data/"
only_file_name = "E10coords365K_75_1_0__114482__8.npy"

coords_files = [only_file_name] # more data can be added to list

# %%
concatenation_points = np.array([], dtype=np.uint32)
count_files = 0
for file_name in coords_files:
    file_snapshots_amount = np.load(path_to_raw_coords + file_name).shape[0]
    if(count_files > 0):
        concatenation_points = np.append(concatenation_points, file_snapshots_amount + concatenation_points[count_files - 1])
    else:
        concatenation_points = np.append(concatenation_points, file_snapshots_amount)
        
    #print(count_files, ",", file_name)
    count_files += 1

concatenation_points -= 1    # get indexes
concatenation_points = np.delete(concatenation_points, -1)

raw_coords = np.concatenate( [np.load(path_to_raw_coords + coords_files[i]).astype(np.float16) for i in range(len(coords_files))] )
#raw_coords = np.load(path_to_raw_coords + 'coords365K_75_1_0__0.npy')
#concatenation_points = np.array([])

raw_z_coords = raw_coords[:, :, 2]

snapshots = raw_coords.shape[0]
atoms = raw_coords.shape[1]
print(snapshots, "snapshots")
print(atoms, "atoms")
test_raw_z_coords = raw_coords[:, :, 2::3].reshape(snapshots, atoms)
# Out:
# 4055 snapshots
# 12235 atoms

# %% [markdown]
# # Plot test snapshot

# %%
# .npy files are already processed, so that the coordinates of particles are measured 
# relative to the center of the condensate

test_snapshot = 0
peptides_amount = 10

fig = plt.figure(figsize=(12,7))
ax = fig.add_subplot(projection='3d')

ax.scatter(*raw_coords[test_snapshot][:-peptides_amount].T, s = 1.5)
ax.scatter(*raw_coords[test_snapshot][-peptides_amount:].T, s = 15)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# ## Detecting condensate's borders

# %%
windows_amounts = int(1000)
extra_space = 1.25
coord_min = np.min(raw_z_coords, axis = -1) * extra_space
coord_max = np.max(raw_z_coords, axis = -1) * extra_space
window_width = (coord_max - coord_min) / float(windows_amounts)

def concentration_from_coords(particles_positions):
    quantized_coords = np.zeros([snapshots, atoms])
    concentration = np.zeros([snapshots, windows_amounts])    
    bins_left_border = np.linspace(coord_min, coord_max, windows_amounts).T
    unique_quantized_coords = []
    concentration = []

    for frame in range(snapshots):
        quantized_coords[frame] = ((raw_z_coords[frame, :]) // window_width[frame]).astype(int)    
        this_frame_unique_quantized_coords, this_frame_concentration = np.unique(quantized_coords[frame], return_counts=True)

        unique_quantized_coords.append(this_frame_unique_quantized_coords)
        concentration.append(this_frame_concentration)
        
    return (unique_quantized_coords, concentration)

# returns nparray with components of left and right border z-coordinate
def detect_condensate_edges(quantized_coords, concentration, threshold_normalized = 0.1):
    borders = np.zeros([snapshots, 2])
    
    conc = concentration
    #print(np.max(conc) * threshold_normalized)
    conc[conc >= np.max(conc) * threshold_normalized] = 0
    
    n = 10
    # n maximum velues
    borders = quantized_coords[(-conc).argsort()[:n]]
    coords_range = np.max(quantized_coords) - np.min(quantized_coords)
    #print(borders)
    while(np.abs(borders[1] - borders[0]) < coords_range * 0.1 and borders.shape[-1] > 2):
        borders = np.delete(borders, 1)
    #print(borders)
    if(borders.shape[-1] >= 2): return borders[:2]
    else: return None
    
    
'''
# CONDENSATE'S BORDERS DETECTION TEST
test_frame = 500
dots = 10

print("borders: ", borders[test_frame])
plt.plot(raw_z_coords[test_frame], '.', markersize = 1.5)
plt.plot(np.linspace(0, atoms, dots), np.repeat(borders[test_frame][0], dots), color='red');
plt.plot(np.linspace(0, atoms, dots), np.repeat(borders[test_frame][1], dots), color='red');'''
# Out:
# '\n# CONDENSATE\'S BORDERS DETECTION TEST\ntest_frame = 500\ndots = 10\n\nprint("borders: ", borders[test_frame])\nplt.plot(raw_z_coords[test_frame], \'.\', markersize = 1.5)\nplt.plot(np.linspace(0, atoms, dots), np.repeat(borders[test_frame][0], dots), color=\'red\');\nplt.plot(np.linspace(0, atoms, dots), np.repeat(borders[test_frame][1], dots), color=\'red\');'

# %% [markdown]
# ## Training data:
# - 10 * 3 numbers: coordinates of every single peptide particle
# - 3 numbers: left, right condensate border, threashold

# %%
peptide_atoms = 10
#condensate_border_threshold

peptide_coords = raw_coords[:, -peptide_atoms:, :].reshape(snapshots, peptide_atoms * 3);

unique_quantized_coords, concentration = concentration_from_coords(raw_z_coords)    #for all frames    
condensate_border_threshold = 0.25
borders = np.zeros([snapshots, 2])

for frame in range(snapshots):
    thisframe_borders = detect_condensate_edges(unique_quantized_coords[frame], concentration[frame], threshold_normalized = condensate_border_threshold)
    borders[frame] = thisframe_borders * window_width[frame]

    
#condensate_threshold_array = np.repeat(condensate_border_threshold, snapshots).reshape(snapshots, 1)
peptide_coords = np.abs(peptide_coords)
traj_whole = peptide_coords.reshape(snapshots, peptide_atoms * 3) #np.concatenate((peptide_coords, borders), axis = 1)
traj_data_points, input_size = traj_whole.shape

# %% [markdown]
# # Initialized the VAMPnets wrapper class

# %%
vamp = vampnet.VampnetTools(epsilon = epsilon)

# %% [markdown]
# # Shuffle trajectory and lagged trajectory together

# %%
length_data = traj_data_points - tau

traj_ord = traj_whole[:length_data, ...]
traj_ord_lag = traj_whole[tau:length_data+tau, ...]

traj_ord = np.delete(traj_ord, concatenation_points, axis = 0)
traj_ord_lag = np.delete(traj_ord_lag, concatenation_points, axis = 0)

length_data -= concatenation_points.size

indexes = np.arange(length_data)
np.random.shuffle(indexes)

traj = traj_ord[indexes]
traj_lag = traj_ord_lag[indexes]

# %% [markdown]
# # Prepare data for tensorflow usage

# %%
length_train = int(np.floor(length_data * train_ratio))
length_vali = length_data - length_train

traj_data_train = traj[:length_train]
traj_data_train_lag = traj_lag[:length_train]

traj_data_valid = traj[length_train:]
traj_data_valid_lag = traj_lag[length_train:]

# Input of the first network
X1_train = traj_data_train.astype('float32')
X2_train  = traj_data_train_lag.astype('float32')

# Input for validation
X1_vali = traj_data_valid.astype('float32')
X2_vali = traj_data_valid_lag.astype('float32')

# Needs a Y-train set which we dont have.
Y_train = np.zeros((length_train,2*output_size)).astype('float32')
Y_vali = np.zeros((length_vali,2*output_size)).astype('float32')

gc.collect()
# Out:
# 3022

# %%
# Build the model

def generate_nodes():
    return [layer_width * layer_width_factor**i for i in range(network_depth)]

nodes = generate_nodes()

Data_X = Input(shape = (input_size,))
Data_Y = Input(shape = (input_size,))

# A batch normalization layer improves convergence speed
bn_layer = BatchNormalization()

# Instance layers and assign them to the two lobes of the network
dense_layers = [Dense(node, activation = 'elu')# if index_layer < 3 else 'linear nodes')
                for index_layer,node in enumerate(nodes)]

lx_branch = bn_layer(Data_X)
rx_branch = bn_layer(Data_Y)

for i, layer in enumerate(dense_layers):

    lx_branch = dense_layers[i](lx_branch)
    rx_branch = dense_layers[i](rx_branch)


# Add a softmax output layer.
# Should be replaced with a linear activation layer if
# the outputs of the network cannot be interpreted as states
softmax = Dense(output_size, activation='softmax')

lx_branch = softmax(lx_branch)
rx_branch = softmax(rx_branch)

# Merge both networks to train both at the same time
merged = concatenate([lx_branch, rx_branch])

# Initialize the model and the optimizer, and compile it with
# the loss and metric functions from the VAMPnets package
model = Model(inputs = [Data_X, Data_Y], outputs = merged)

model.summary()

gc.collect()
# Out:
# WARNING:tensorflow:From /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 30)           120         input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 250)          7750        batch_normalization[0][0]
#                                                                  batch_normalization[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 187)          46937       dense[0][0]
#                                                                  dense[1][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 140)          26320       dense_1[0][0]
#                                                                  dense_1[1][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 105)          14805       dense_2[0][0]
#                                                                  dense_2[1][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 79)           8374        dense_3[0][0]
#                                                                  dense_3[1][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            160         dense_4[0][0]
#                                                                  dense_4[1][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4)            0           dense_5[0][0]
#                                                                  dense_5[1][0]
# ==================================================================================================
# Total params: 104,466
# Trainable params: 104,406
# Non-trainable params: 60
# __________________________________________________________________________________________________
# 8

# %% [markdown]
# # Run several model iterations saving the best one, to help finding sparcely populated states

# %%
#from tensorflow.python.keras.utils.data_utils import Sequence
from tensorflow.python.keras.callbacks import CSVLogger

checkpoint_path = "model_checkpoints/"

csv_logger = CSVLogger(model_name + 'log.csv', append=True, separator=';')

my_callbacks = [
    csv_logger,
    tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=2)
]

max_vm = 0
attempts = 3
found_better_weights = 0

# IMPORTANT: the function vamp.loss_VAMP2_autograd can only be used with tensorflow 1.6 or more recent.
# For older versions of TF, use the function vamp.loss_VAMP2

losses = [
    vamp.loss_VAMP2_autograd,
]


for i in range(attempts):    
    print("Attempt", i)
    # Clear the previous tensorflow session to prevent memory leaks
    clear_session()

    # Build the model


    nodes = generate_nodes() #[layer_width]*network_depth

    Data_X = Input(shape = (input_size,))
    Data_Y = Input(shape = (input_size,))

    # A batch normalization layer improves convergence speed
    bn_layer = BatchNormalization()

    # Instance layers and assign them to the two lobes of the network
    dense_layers = [Dense(node, activation = 'elu')# if index_layer < 3 else 'linear nodes')
                    for index_layer,node in enumerate(nodes)]

    lx_branch = bn_layer(Data_X)
    rx_branch = bn_layer(Data_Y)

    for i, layer in enumerate(dense_layers):
        
        lx_branch = dense_layers[i](lx_branch)
        rx_branch = dense_layers[i](rx_branch)


    # Add a softmax output layer.
    # Should be replaced with a linear activation layer if
    # the outputs of the network cannot be interpreted as states
    softmax = Dense(output_size, activation='softmax')

    lx_branch = softmax(lx_branch)
    rx_branch = softmax(rx_branch)

    # Merge both networks to train both at the same time
    merged = concatenate([lx_branch, rx_branch])

    # Initialize the model and the optimizer, and compile it with
    # the loss and metric functions from the VAMPnets package
    model = Model(inputs = [Data_X, Data_Y], outputs = merged)
    adam = Adam(lr = learning_rate/10)

    vm1 = np.zeros((len(losses), nb_epoch))
    tm1 = np.zeros_like(vm1)
    vm2 = np.zeros_like(vm1)
    tm2 = np.zeros_like(vm1)
    vm3 = np.zeros_like(vm1)
    tm3 = np.zeros_like(vm1)

    for l_index, loss_function in enumerate(losses):
        
        model.compile(optimizer = adam,
                      loss = loss_function,
                      metrics = [
                          vamp.metric_VAMP,
                          vamp.metric_VAMP2,
                                 ])
        
        # Train the model
        print("Started training model.")        
        gc.collect()
        
        hist = model.fit([X1_train, X2_train], Y_train ,
                         #batch_size=batch_size,
                         epochs=nb_epoch,
                         validation_data=([X1_vali, X2_vali], Y_vali ),
                         verbose=1, callbacks=my_callbacks)

        gc.collect()

        vm1[l_index] = np.array(hist.history['val_metric_VAMP'])
        tm1[l_index] = np.array(hist.history['metric_VAMP'])


        vm2[l_index] = np.array(hist.history['val_metric_VAMP2'])
        tm2[l_index] = np.array(hist.history['metric_VAMP2'])

        vm3[l_index] = np.array(hist.history['val_loss'])
        tm3[l_index] = np.array(hist.history['loss'])


    vm1 = np.reshape(vm1, (-1))
    tm1 = np.reshape(tm1, (-1))
    vm2 = np.reshape(vm2, (-1))
    tm2 = np.reshape(tm2, (-1))
    vm3 = np.reshape(vm3, (-1))
    tm3 = np.reshape(tm3, (-1))

    # Average the score obtained in the last part of the training process
    # in order to estabilish which model is better and thus worth saving


    score = vm1[-5:].mean()
    extra_msg = ''
    if score > max_vm:
        found_better_weights += 1
        extra_msg = ' - Highest'
        best_weights = model.get_weights()
        np.save("weights/" + model_name, best_weights, allow_pickle=True)
        max_vm = score
        vm1_max = vm1
        tm1_max = tm1
        vm2_max = vm2
        tm2_max = tm2
        vm3_max = vm3
        tm3_max = tm3

    print('Score: {0:.2f}'.format(score) + extra_msg)
    gc.collect()
# Out:
# Attempt 0
# WARNING:tensorflow:From /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/vampnet-0.1.4.dev16+gc88ed3f-py3.7.egg/vampnet/vampnet.py:660: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/vampnet-0.1.4.dev16+gc88ed3f-py3.7.egg/vampnet/vampnet.py:608: The name tf.self_adjoint_eig is deprecated. Please use tf.linalg.eigh instead.
#
# WARNING:tensorflow:From /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/vampnet-0.1.4.dev16+gc88ed3f-py3.7.egg/vampnet/vampnet.py:612: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/vampnet-0.1.4.dev16+gc88ed3f-py3.7.egg/vampnet/vampnet.py:618: The name tf.diag is deprecated. Please use tf.linalg.tensor_diag instead.
#
# WARNING:tensorflow:From /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/vampnet-0.1.4.dev16+gc88ed3f-py3.7.egg/vampnet/vampnet.py:268: The name tf.svd is deprecated. Please use tf.linalg.svd instead.
#
# Started training model.
# Train on 3645 samples, validate on 405 samples
# 2022-10-31 17:53:41.728231: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-31 17:53:41.753373: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3000000000 Hz
# 2022-10-31 17:53:41.753969: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c7777bb6a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-10-31 17:53:41.754009: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# OMP: Info #212: KMP_AFFINITY: decoding x2APIC ids.
# OMP: Info #210: KMP_AFFINITY: Affinity capable, using global cpuid leaf 11 info
# OMP: Info #154: KMP_AFFINITY: Initial OS proc set respected: 0-7
# OMP: Info #156: KMP_AFFINITY: 8 available OS procs
# OMP: Info #157: KMP_AFFINITY: Uniform topology
# OMP: Info #179: KMP_AFFINITY: 1 packages x 8 cores/pkg x 1 threads/core (8 total cores)
# OMP: Info #214: KMP_AFFINITY: OS proc to physical thread map:
# OMP: Info #171: KMP_AFFINITY: OS proc 0 maps to package 0 core 0
# OMP: Info #171: KMP_AFFINITY: OS proc 1 maps to package 0 core 1
# OMP: Info #171: KMP_AFFINITY: OS proc 2 maps to package 0 core 2
# OMP: Info #171: KMP_AFFINITY: OS proc 3 maps to package 0 core 3
# OMP: Info #171: KMP_AFFINITY: OS proc 4 maps to package 0 core 4
# OMP: Info #171: KMP_AFFINITY: OS proc 5 maps to package 0 core 5
# OMP: Info #171: KMP_AFFINITY: OS proc 6 maps to package 0 core 6
# OMP: Info #171: KMP_AFFINITY: OS proc 7 maps to package 0 core 7
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25654 thread 0 bound to OS proc set 0
# 2022-10-31 17:53:41.762447: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/300
# 1120/3645 [========>.....................] - ETA: 2s - loss: -0.7698 - metric_VAMP: 0.8716 - metric_VAMP2: 0.7698
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25708 thread 1 bound to OS proc set 1
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25709 thread 2 bound to OS proc set 2
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25713 thread 3 bound to OS proc set 3
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25714 thread 4 bound to OS proc set 4
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25715 thread 5 bound to OS proc set 5
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25716 thread 6 bound to OS proc set 6
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25717 thread 7 bound to OS proc set 7
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25718 thread 8 bound to OS proc set 0
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25719 thread 9 bound to OS proc set 1
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25720 thread 10 bound to OS proc set 2
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25721 thread 11 bound to OS proc set 3
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25722 thread 12 bound to OS proc set 4
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25723 thread 13 bound to OS proc set 5
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25725 thread 15 bound to OS proc set 7
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25724 thread 14 bound to OS proc set 6
# OMP: Info #250: KMP_AFFINITY: pid 25654 tid 25726 thread 16 bound to OS proc set 0
# 3616/3645 [============================>.] - ETA: 0s - loss: -0.8921 - metric_VAMP: 0.9416 - metric_VAMP2: 0.8921
# Epoch 00001: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 2s 508us/sample - loss: -0.8928 - metric_VAMP: 0.9420 - metric_VAMP2: 0.8928 - val_loss: -0.9564 - val_metric_VAMP: 0.9780 - val_metric_VAMP2: 0.9565
# Epoch 2/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9746 - metric_VAMP: 0.9872 - metric_VAMP2: 0.9746
# Epoch 00002: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9752 - metric_VAMP: 0.9875 - metric_VAMP2: 0.9752 - val_loss: -0.9800 - val_metric_VAMP: 0.9899 - val_metric_VAMP2: 0.9800
# Epoch 3/300
# 3136/3645 [========================>.....] - ETA: 0s - loss: -0.9839 - metric_VAMP: 0.9919 - metric_VAMP2: 0.9839
# Epoch 00003: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 138us/sample - loss: -0.9841 - metric_VAMP: 0.9920 - metric_VAMP2: 0.9841 - val_loss: -0.9850 - val_metric_VAMP: 0.9926 - val_metric_VAMP2: 0.9852
# Epoch 4/300
# 3552/3645 [============================>.] - ETA: 0s - loss: -0.9867 - metric_VAMP: 0.9933 - metric_VAMP2: 0.9867
# Epoch 00004: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 165us/sample - loss: -0.9867 - metric_VAMP: 0.9933 - metric_VAMP2: 0.9867 - val_loss: -0.9879 - val_metric_VAMP: 0.9940 - val_metric_VAMP2: 0.9879
# Epoch 5/300
# 3136/3645 [========================>.....] - ETA: 0s - loss: -0.9889 - metric_VAMP: 0.9944 - metric_VAMP2: 0.9889
# Epoch 00005: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 139us/sample - loss: -0.9888 - metric_VAMP: 0.9944 - metric_VAMP2: 0.9888 - val_loss: -0.9891 - val_metric_VAMP: 0.9945 - val_metric_VAMP2: 0.9891
# Epoch 6/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9899 - metric_VAMP: 0.9949 - metric_VAMP2: 0.9899
# Epoch 00006: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9900 - metric_VAMP: 0.9950 - metric_VAMP2: 0.9900 - val_loss: -0.9906 - val_metric_VAMP: 0.9953 - val_metric_VAMP2: 0.9906
# Epoch 7/300
# 3264/3645 [=========================>....] - ETA: 0s - loss: -0.9910 - metric_VAMP: 0.9955 - metric_VAMP2: 0.9910
# Epoch 00007: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 135us/sample - loss: -0.9911 - metric_VAMP: 0.9955 - metric_VAMP2: 0.9911 - val_loss: -0.9912 - val_metric_VAMP: 0.9956 - val_metric_VAMP2: 0.9912
# Epoch 8/300
# 3616/3645 [============================>.] - ETA: 0s - loss: -0.9917 - metric_VAMP: 0.9959 - metric_VAMP2: 0.9917
# Epoch 00008: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9917 - metric_VAMP: 0.9958 - metric_VAMP2: 0.9917 - val_loss: -0.9915 - val_metric_VAMP: 0.9958 - val_metric_VAMP2: 0.9916
# Epoch 9/300
# 3264/3645 [=========================>....] - ETA: 0s - loss: -0.9923 - metric_VAMP: 0.9962 - metric_VAMP2: 0.9923
# Epoch 00009: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 149us/sample - loss: -0.9923 - metric_VAMP: 0.9961 - metric_VAMP2: 0.9923 - val_loss: -0.9918 - val_metric_VAMP: 0.9959 - val_metric_VAMP2: 0.9918
# Epoch 10/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9924 - metric_VAMP: 0.9962 - metric_VAMP2: 0.9924
# Epoch 00010: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 139us/sample - loss: -0.9925 - metric_VAMP: 0.9963 - metric_VAMP2: 0.9925 - val_loss: -0.9926 - val_metric_VAMP: 0.9963 - val_metric_VAMP2: 0.9925
# Epoch 11/300
# 3264/3645 [=========================>....] - ETA: 0s - loss: -0.9928 - metric_VAMP: 0.9964 - metric_VAMP2: 0.9928
# Epoch 00011: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 151us/sample - loss: -0.9929 - metric_VAMP: 0.9964 - metric_VAMP2: 0.9929 - val_loss: -0.9920 - val_metric_VAMP: 0.9960 - val_metric_VAMP2: 0.9921
# Epoch 12/300
# 3584/3645 [============================>.] - ETA: 0s - loss: -0.9934 - metric_VAMP: 0.9967 - metric_VAMP2: 0.9934
# Epoch 00012: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 145us/sample - loss: -0.9934 - metric_VAMP: 0.9967 - metric_VAMP2: 0.9934 - val_loss: -0.9928 - val_metric_VAMP: 0.9964 - val_metric_VAMP2: 0.9928
# Epoch 13/300
# 3296/3645 [==========================>...] - ETA: 0s - loss: -0.9937 - metric_VAMP: 0.9968 - metric_VAMP2: 0.9937
# Epoch 00013: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 148us/sample - loss: -0.9936 - metric_VAMP: 0.9968 - metric_VAMP2: 0.9936 - val_loss: -0.9927 - val_metric_VAMP: 0.9964 - val_metric_VAMP2: 0.9927
# Epoch 14/300
# 3136/3645 [========================>.....] - ETA: 0s - loss: -0.9937 - metric_VAMP: 0.9969 - metric_VAMP2: 0.9937
# Epoch 00014: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 138us/sample - loss: -0.9935 - metric_VAMP: 0.9967 - metric_VAMP2: 0.9935 - val_loss: -0.9932 - val_metric_VAMP: 0.9966 - val_metric_VAMP2: 0.9932
# Epoch 15/300
# 3328/3645 [==========================>...] - ETA: 0s - loss: -0.9943 - metric_VAMP: 0.9971 - metric_VAMP2: 0.9943
# Epoch 00015: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 129us/sample - loss: -0.9943 - metric_VAMP: 0.9971 - metric_VAMP2: 0.9943 - val_loss: -0.9931 - val_metric_VAMP: 0.9965 - val_metric_VAMP2: 0.9931
# Epoch 16/300
# 3552/3645 [============================>.] - ETA: 0s - loss: -0.9940 - metric_VAMP: 0.9970 - metric_VAMP2: 0.9940
# Epoch 00016: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9941 - metric_VAMP: 0.9970 - metric_VAMP2: 0.9941 - val_loss: -0.9927 - val_metric_VAMP: 0.9964 - val_metric_VAMP2: 0.9928
# Epoch 17/300
# 3136/3645 [========================>.....] - ETA: 0s - loss: -0.9943 - metric_VAMP: 0.9972 - metric_VAMP2: 0.9943
# Epoch 00017: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9943 - metric_VAMP: 0.9971 - metric_VAMP2: 0.9943 - val_loss: -0.9936 - val_metric_VAMP: 0.9968 - val_metric_VAMP2: 0.9936
# Epoch 18/300
# 3104/3645 [========================>.....] - ETA: 0s - loss: -0.9946 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9946
# Epoch 00018: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 139us/sample - loss: -0.9945 - metric_VAMP: 0.9972 - metric_VAMP2: 0.9945 - val_loss: -0.9938 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9938
# Epoch 19/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9947 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9947
# Epoch 00019: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9945 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9945 - val_loss: -0.9939 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9939
# Epoch 20/300
# 3200/3645 [=========================>....] - ETA: 0s - loss: -0.9947 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9947
# Epoch 00020: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 136us/sample - loss: -0.9948 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9948 - val_loss: -0.9940 - val_metric_VAMP: 0.9970 - val_metric_VAMP2: 0.9940
# Epoch 21/300
# 3264/3645 [=========================>....] - ETA: 0s - loss: -0.9951 - metric_VAMP: 0.9975 - metric_VAMP2: 0.9951
# Epoch 00021: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 144us/sample - loss: -0.9950 - metric_VAMP: 0.9975 - metric_VAMP2: 0.9950 - val_loss: -0.9940 - val_metric_VAMP: 0.9970 - val_metric_VAMP2: 0.9939
# Epoch 22/300
# 3200/3645 [=========================>....] - ETA: 0s - loss: -0.9948 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9948
# Epoch 00022: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 120us/sample - loss: -0.9949 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9949 - val_loss: -0.9939 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9939
# Epoch 23/300
# 3584/3645 [============================>.] - ETA: 0s - loss: -0.9948 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9948
# Epoch 00023: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 140us/sample - loss: -0.9948 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9948 - val_loss: -0.9941 - val_metric_VAMP: 0.9971 - val_metric_VAMP2: 0.9942
# Epoch 24/300
# 3328/3645 [==========================>...] - ETA: 0s - loss: -0.9949 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9949
# Epoch 00024: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 130us/sample - loss: -0.9949 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9949 - val_loss: -0.9944 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9944
# Epoch 25/300
# 3232/3645 [=========================>....] - ETA: 0s - loss: -0.9951 - metric_VAMP: 0.9975 - metric_VAMP2: 0.9951
# Epoch 00025: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 135us/sample - loss: -0.9950 - metric_VAMP: 0.9975 - metric_VAMP2: 0.9950 - val_loss: -0.9936 - val_metric_VAMP: 0.9968 - val_metric_VAMP2: 0.9937
# Epoch 26/300
# 3552/3645 [============================>.] - ETA: 0s - loss: -0.9948 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9948
# Epoch 00026: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9949 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9949 - val_loss: -0.9943 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9943
# Epoch 27/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9952 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9952
# Epoch 00027: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 133us/sample - loss: -0.9951 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9951 - val_loss: -0.9937 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9938
# Epoch 28/300
# 3360/3645 [==========================>...] - ETA: 0s - loss: -0.9952 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9952
# Epoch 00028: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 142us/sample - loss: -0.9952 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9952 - val_loss: -0.9941 - val_metric_VAMP: 0.9971 - val_metric_VAMP2: 0.9942
# Epoch 29/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9952 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9952
# Epoch 00029: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 129us/sample - loss: -0.9952 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9952 - val_loss: -0.9942 - val_metric_VAMP: 0.9971 - val_metric_VAMP2: 0.9943
# Epoch 30/300
# 3136/3645 [========================>.....] - ETA: 0s - loss: -0.9951 - metric_VAMP: 0.9975 - metric_VAMP2: 0.9951
# Epoch 00030: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 138us/sample - loss: -0.9951 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9951 - val_loss: -0.9942 - val_metric_VAMP: 0.9970 - val_metric_VAMP2: 0.9940
# Epoch 31/300
# 3200/3645 [=========================>....] - ETA: 0s - loss: -0.9954 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9954
# Epoch 00031: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9954 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9954 - val_loss: -0.9941 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9937
# Epoch 32/300
# 3136/3645 [========================>.....] - ETA: 0s - loss: -0.9953 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9953
# Epoch 00032: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 139us/sample - loss: -0.9953 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9953 - val_loss: -0.9942 - val_metric_VAMP: 0.9970 - val_metric_VAMP2: 0.9940
# Epoch 33/300
# 3136/3645 [========================>.....] - ETA: 0s - loss: -0.9954 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9954
# Epoch 00033: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 137us/sample - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955 - val_loss: -0.9943 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9944
# Epoch 34/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9953 - metric_VAMP: 0.9976 - metric_VAMP2: 0.9953
# Epoch 00034: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 145us/sample - loss: -0.9954 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9954 - val_loss: -0.9938 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9938
# Epoch 35/300
# 3296/3645 [==========================>...] - ETA: 0s - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956
# Epoch 00035: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 133us/sample - loss: -0.9955 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9955 - val_loss: -0.9945 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9945
# Epoch 36/300
# 3328/3645 [==========================>...] - ETA: 0s - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956
# Epoch 00036: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 136us/sample - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956 - val_loss: -0.9943 - val_metric_VAMP: 0.9971 - val_metric_VAMP2: 0.9943
# Epoch 37/300
# 3232/3645 [=========================>....] - ETA: 0s - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955
# Epoch 00037: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 137us/sample - loss: -0.9954 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9954 - val_loss: -0.9945 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9944
# Epoch 38/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955
# Epoch 00038: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 143us/sample - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955 - val_loss: -0.9946 - val_metric_VAMP: 0.9973 - val_metric_VAMP2: 0.9945
# Epoch 39/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957
# Epoch 00039: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 142us/sample - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955 - val_loss: -0.9944 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9944
# Epoch 40/300
# 3328/3645 [==========================>...] - ETA: 0s - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955
# Epoch 00040: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 131us/sample - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955 - val_loss: -0.9945 - val_metric_VAMP: 0.9973 - val_metric_VAMP2: 0.9946
# Epoch 41/300
# 3360/3645 [==========================>...] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9957
# Epoch 00041: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 173us/sample - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955 - val_loss: -0.9941 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9938
# Epoch 42/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957
# Epoch 00042: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 138us/sample - loss: -0.9957 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9957 - val_loss: -0.9945 - val_metric_VAMP: 0.9973 - val_metric_VAMP2: 0.9946
# Epoch 43/300
# 3552/3645 [============================>.] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9957
# Epoch 00043: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 143us/sample - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957 - val_loss: -0.9938 - val_metric_VAMP: 0.9969 - val_metric_VAMP2: 0.9939
# Epoch 44/300
# 3296/3645 [==========================>...] - ETA: 0s - loss: -0.9955 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9955
# Epoch 00044: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 137us/sample - loss: -0.9955 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9955 - val_loss: -0.9944 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9944
# Epoch 45/300
# 3552/3645 [============================>.] - ETA: 0s - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955
# Epoch 00045: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 130us/sample - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955 - val_loss: -0.9946 - val_metric_VAMP: 0.9973 - val_metric_VAMP2: 0.9947
# Epoch 46/300
# 3232/3645 [=========================>....] - ETA: 0s - loss: -0.9955 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9955
# Epoch 00046: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 139us/sample - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956 - val_loss: -0.9945 - val_metric_VAMP: 0.9973 - val_metric_VAMP2: 0.9946
# Epoch 47/300
# 3584/3645 [============================>.] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957
# Epoch 00047: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 144us/sample - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957 - val_loss: -0.9945 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9945
# Epoch 48/300
# 3392/3645 [==========================>...] - ETA: 0s - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956
# Epoch 00048: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 150us/sample - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956 - val_loss: -0.9944 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9944
# Epoch 49/300
# 3552/3645 [============================>.] - ETA: 0s - loss: -0.9958 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9958
# Epoch 00049: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 143us/sample - loss: -0.9958 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9958 - val_loss: -0.9943 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9944
# Epoch 50/300
# 3104/3645 [========================>.....] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957
# Epoch 00050: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 140us/sample - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956 - val_loss: -0.9943 - val_metric_VAMP: 0.9971 - val_metric_VAMP2: 0.9942
# Epoch 51/300
# 3488/3645 [===========================>..] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9957
# Epoch 00051: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 148us/sample - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957 - val_loss: -0.9945 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9945
# Epoch 52/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9959 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9959
# Epoch 00052: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 140us/sample - loss: -0.9958 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9958 - val_loss: -0.9946 - val_metric_VAMP: 0.9973 - val_metric_VAMP2: 0.9946
# Epoch 53/300
# 3168/3645 [=========================>....] - ETA: 0s - loss: -0.9954 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9954
# Epoch 00053: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 141us/sample - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956 - val_loss: -0.9948 - val_metric_VAMP: 0.9974 - val_metric_VAMP2: 0.9948
# Epoch 54/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956
# Epoch 00054: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 142us/sample - loss: -0.9956 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956 - val_loss: -0.9947 - val_metric_VAMP: 0.9973 - val_metric_VAMP2: 0.9946
# Epoch 55/300
# 3520/3645 [===========================>..] - ETA: 0s - loss: -0.9958 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9958
# Epoch 00055: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 144us/sample - loss: -0.9958 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9958 - val_loss: -0.9942 - val_metric_VAMP: 0.9971 - val_metric_VAMP2: 0.9942
# Epoch 56/300
# 3104/3645 [========================>.....] - ETA: 0s - loss: -0.9958 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9958
# Epoch 00056: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c35063dd0>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 138us/sample - loss: -0.9957 - metric_VAMP: 0.9979 - metric_VAMP2: 0.9957 - val_loss: -0.9945 - val_metric_VAMP: 0.9972 - val_metric_VAMP2: 0.9943
# Epoch 57/300
# 3232/3645 [=========================>....] - ETA: 0s - loss: -0.9955 - metric_VAMP: 0.9977 - metric_VAMP2: 0.9955
# Epoch 00057: saving model to model_checkpoints/
# ...
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 147us/sample - loss: -0.9881 - metric_VAMP: 0.9941 - metric_VAMP2: 0.9881 - val_loss: -0.9871 - val_metric_VAMP: 0.9935 - val_metric_VAMP2: 0.9871
# Epoch 5/300
# 3232/3645 [=========================>....] - ETA: 0s - loss: -0.9896 - metric_VAMP: 0.9948 - metric_VAMP2: 0.9896
# Epoch 00005: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 136us/sample - loss: -0.9898 - metric_VAMP: 0.9949 - metric_VAMP2: 0.9898 - val_loss: -0.9889 - val_metric_VAMP: 0.9942 - val_metric_VAMP2: 0.9885
# Epoch 6/300
# 3328/3645 [==========================>...] - ETA: 0s - loss: -0.9910 - metric_VAMP: 0.9955 - metric_VAMP2: 0.9910
# Epoch 00006: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 149us/sample - loss: -0.9909 - metric_VAMP: 0.9954 - metric_VAMP2: 0.9909 - val_loss: -0.9900 - val_metric_VAMP: 0.9949 - val_metric_VAMP2: 0.9899
# Epoch 7/300
# 3488/3645 [===========================>..] - ETA: 0s - loss: -0.9919 - metric_VAMP: 0.9959 - metric_VAMP2: 0.9919
# Epoch 00007: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 144us/sample - loss: -0.9919 - metric_VAMP: 0.9959 - metric_VAMP2: 0.9919 - val_loss: -0.9913 - val_metric_VAMP: 0.9956 - val_metric_VAMP2: 0.9912
# Epoch 8/300
# 3392/3645 [==========================>...] - ETA: 0s - loss: -0.9925 - metric_VAMP: 0.9962 - metric_VAMP2: 0.9925
# Epoch 00008: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 145us/sample - loss: -0.9925 - metric_VAMP: 0.9963 - metric_VAMP2: 0.9925 - val_loss: -0.9918 - val_metric_VAMP: 0.9958 - val_metric_VAMP2: 0.9917
# Epoch 9/300
# 3520/3645 [===========================>..] - ETA: 0s - loss: -0.9931 - metric_VAMP: 0.9965 - metric_VAMP2: 0.9931
# Epoch 00009: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 140us/sample - loss: -0.9931 - metric_VAMP: 0.9965 - metric_VAMP2: 0.9931 - val_loss: -0.9918 - val_metric_VAMP: 0.9959 - val_metric_VAMP2: 0.9918
# Epoch 10/300
# 3456/3645 [===========================>..] - ETA: 0s - loss: -0.9934 - metric_VAMP: 0.9967 - metric_VAMP2: 0.9934
# Epoch 00010: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 148us/sample - loss: -0.9934 - metric_VAMP: 0.9967 - metric_VAMP2: 0.9934 - val_loss: -0.9925 - val_metric_VAMP: 0.9962 - val_metric_VAMP2: 0.9923
# Epoch 11/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9940 - metric_VAMP: 0.9970 - metric_VAMP2: 0.9940
# Epoch 00011: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 147us/sample - loss: -0.9940 - metric_VAMP: 0.9970 - metric_VAMP2: 0.9940 - val_loss: -0.9925 - val_metric_VAMP: 0.9963 - val_metric_VAMP2: 0.9926
# Epoch 12/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9941 - metric_VAMP: 0.9970 - metric_VAMP2: 0.9941
# Epoch 00012: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 146us/sample - loss: -0.9941 - metric_VAMP: 0.9970 - metric_VAMP2: 0.9941 - val_loss: -0.9929 - val_metric_VAMP: 0.9964 - val_metric_VAMP2: 0.9928
# Epoch 13/300
# 3456/3645 [===========================>..] - ETA: 0s - loss: -0.9945 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9945
# Epoch 00013: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 150us/sample - loss: -0.9946 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9946 - val_loss: -0.9932 - val_metric_VAMP: 0.9966 - val_metric_VAMP2: 0.9931
# Epoch 14/300
# 3488/3645 [===========================>..] - ETA: 0s - loss: -0.9945 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9945
# Epoch 00014: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 0s 130us/sample - loss: -0.9945 - metric_VAMP: 0.9972 - metric_VAMP2: 0.9945 - val_loss: -0.9933 - val_metric_VAMP: 0.9967 - val_metric_VAMP2: 0.9934
# Epoch 15/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9946 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9946
# Epoch 00015: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3645/3645 [==============================] - 1s 143us/sample - loss: -0.9947 - metric_VAMP: 0.9973 - metric_VAMP2: 0.9947 - val_loss: -0.9932 - val_metric_VAMP: 0.9966 - val_metric_VAMP2: 0.9932
# Epoch 16/300
# 3424/3645 [===========================>..] - ETA: 0s - loss: -0.9950 - metric_VAMP: 0.9975 - metric_VAMP2: 0.9950
# Epoch 00016: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7f2c34cd6690>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_25654/456469146.py in <module>
#      94                          epochs=nb_epoch,
#      95                          validation_data=([X1_vali, X2_vali], Y_vali ),
# ---> 96                          verbose=1, callbacks=my_callbacks)
#      97
#      98         gc.collect()
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     448     if mode == ModeKeys.TRAIN:
#     449       # Epochs only apply to `fit`.
# --> 450       callbacks.on_epoch_end(epoch, epoch_logs)
#     451     progbar.on_epoch_end(epoch, epoch_logs)
#     452
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     297     logs = logs or {}
#     298     for callback in self.callbacks:
# --> 299       callback.on_epoch_end(epoch, logs)
#     300
#     301   def on_train_batch_begin(self, batch, logs=None):
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     966           self._save_model(epoch=epoch, logs=logs)
#     967       else:
# --> 968         self._save_model(epoch=epoch, logs=logs)
#     969     if self.model._in_multi_worker_mode():
#     970       # For multi-worker training, back up the weights and current training
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/callbacks.py in _save_model(self, epoch, logs)
#    1011           print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1012         if self.save_weights_only:
# -> 1013           self.model.save_weights(filepath, overwrite=True)
#    1014         else:
#    1015           self.model.save(filepath, overwrite=True)
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py in save_weights(self, filepath, overwrite, save_format)
#    1284              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1285             % (optimizer,))
# -> 1286       self._trackable_saver.save(filepath, session=session)
#    1287       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1288       checkpoint_management.update_checkpoint_state_internal(
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/training/tracking/util.py in save(self, file_prefix, checkpoint_number, session)
#    1162
#    1163     if session:
# -> 1164       return session.run(save_path, feed_dict=feed_dict)
#    1165     else:
#    1166       return save_path
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
gc.collect(generation=2)
max_vm
# Out:
# 0.9973742485046386

# %%
! free -g
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:              15           1           0           0          13          13
# Swap:              0           0           0

# %%
temp = model.predict([traj_ord, traj_ord_lag], batch_size=np.shape(X1_vali)[0])
    
x_a = temp[:,:output_size]

average_peptide_z = np.average((traj_ord)[:, :-3][:, 2::3], axis = 1)
average_condesate_width = np.average(np.abs(traj_ord[:, -1] - traj_ord[:, -2]))

plt.clf()
X_Validation = average_peptide_z
for i in range(output_size):
    plt.scatter(X_Validation, x_a[:,i], label= 'state '+str(i), s=0.5)
plt.title('E10 State probabilities')
plt.xlabel("Distance to condensate")
plt.ylabel("Probability")


# plot condensate borders
dots = 10
yline = np.linspace(np.min(x_a[:,i]), np.max(x_a[:,i]), dots)
#plt.plot(- np.repeat(average_condesate_width, dots)/ 2, yline, color = 'black')
plt.plot(+ np.repeat(average_condesate_width, dots)/ 2, yline, color = 'black', label= 'condensate borders')

plt.legend()
plt.show()

# %%
# Over time

test_snapshots = 500
state_probability = x_a[:test_snapshots,:]


fig, ax1 = plt.subplots()

## probability of frame (time)
#plt.clf()
for i in (range(output_size)):
    ax1.plot(np.arange(state_probability.shape[0]), state_probability[:, i], label= 'state '+str(i))

velocity_time_lag = 1
average_peptide_z_velocity = average_peptide_z[velocity_time_lag:] - average_peptide_z[:velocity_time_lag]

velocity_scale_factor = np.max(average_peptide_z_velocity)
average_peptide_z_velocity_normalized = average_peptide_z_velocity / velocity_scale_factor

ax1.plot(average_peptide_z_velocity_normalized[:test_snapshots], label = "z-velocity")      

ax1.xaxis.set_ticklabels(np.arange(state_probability.shape[0]) * picoseconds_per_step * 10**-3)
plt.xlabel("Time, ns")
plt.ylabel("Probability")

ax2 = ax1.twinx()
ax2.set_ylabel("Peptide CoM velocity, pm/ns")
ax2.set_ylim(0, 60)
ax2.set_yticks(np.linspace(0, 1, 6) * velocity_scale_factor)
ax2.set_yticklabels(np.round(np.linspace(-1, 1, 6) * velocity_scale_factor / picoseconds_per_step, 2))

ax1.legend()
plt.show()
# Out:
# /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# # Save model weights

# %%
best_weights = model.get_weights()
np.save("weights/" + model_name, best_weights, allow_pickle=True)
# Out:
# /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %% [markdown]
# # Recover the saved model and its training history

# %%
#model.load_weights(checkpoint_path)                   #from checkpoint
weights = np.load("weights/" + model_name+ ".npy", allow_pickle=True) #.tolist()
model.set_weights((weights).tolist() )    #from nparray

# %% [markdown]
# ## Continue training the recovered model

# %%
weights_file_name = "best_weights"
found_better_weights = 0

max_vm = 0

# IMPORTANT: the function vamp.loss_VAMP2_autograd can only be used with tensorflow 1.6 or more recent.
# For older versions of TF, use the function vamp.loss_VAMP2

from tensorflow.python.keras.callbacks import CSVLogger

checkpoint_path = "model_checkpoints/"

csv_logger = CSVLogger(model_name + 'log.csv', append=True, separator=';')

my_callbacks = [
    csv_logger,
    tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=2)
]

################
# SETUP MODEL
################

# Clear the previous tensorflow session to prevent memory leaks
clear_session()

# Build the model


nodes = generate_nodes()

Data_X = Input(shape = (input_size,))
Data_Y = Input(shape = (input_size,))

# A batch normalization layer improves convergence speed
bn_layer = BatchNormalization()

# Instance layers and assign them to the two lobes of the network
dense_layers = [Dense(node, activation = 'elu')# if index_layer < 3 else 'linear nodes')
                for index_layer,node in enumerate(nodes)]

lx_branch = bn_layer(Data_X)
rx_branch = bn_layer(Data_Y)

for i, layer in enumerate(dense_layers):

    lx_branch = dense_layers[i](lx_branch)
    rx_branch = dense_layers[i](rx_branch)


# Add a softmax output layer.
# Should be replaced with a linear activation layer if
# the outputs of the network cannot be interpreted as states
softmax = Dense(output_size, activation='softmax')

lx_branch = softmax(lx_branch)
rx_branch = softmax(rx_branch)

# Merge both networks to train both at the same time
merged = concatenate([lx_branch, rx_branch])

# Initialize the model and the optimizer, and compile it with
# the loss and metric functions from the VAMPnets package
model = Model(inputs = [Data_X, Data_Y], outputs = merged)
adam = Adam(lr = learning_rate/10)

vm1 = np.zeros((len(losses), nb_epoch))
tm1 = np.zeros_like(vm1)
vm2 = np.zeros_like(vm1)
tm2 = np.zeros_like(vm1)
vm3 = np.zeros_like(vm1)
tm3 = np.zeros_like(vm1)

weights = np.load("weights/" + model_name+ ".npy", allow_pickle=True) #.tolist()
model.set_weights((weights).tolist() )    #from nparray


for l_index, loss_function in enumerate(losses):
        
    model.compile(optimizer = adam,
                  loss = loss_function,
                  metrics = [
                      vamp.metric_VAMP,
                      vamp.metric_VAMP2,
                             ])

    # Train the model
    print("Started training model.")        
    hist = model.fit([X1_train, X2_train], Y_train ,
                     #batch_size=batch_size,
                     epochs=nb_epoch,
                     validation_data=([X1_vali, X2_vali], Y_vali ),
                     verbose=1, callbacks=my_callbacks)


    vm1[l_index] = np.array(hist.history['val_metric_VAMP'])
    tm1[l_index] = np.array(hist.history['metric_VAMP'])


    vm2[l_index] = np.array(hist.history['val_metric_VAMP2'])
    tm2[l_index] = np.array(hist.history['metric_VAMP2'])

    vm3[l_index] = np.array(hist.history['val_loss'])
    tm3[l_index] = np.array(hist.history['loss'])


vm1 = np.reshape(vm1, (-1))
tm1 = np.reshape(tm1, (-1))
vm2 = np.reshape(vm2, (-1))
tm2 = np.reshape(tm2, (-1))
vm3 = np.reshape(vm3, (-1))
tm3 = np.reshape(tm3, (-1))

# Average the score obtained in the last part of the training process
# in order to estabilish which model is better and thus worth saving


score = vm1[-5:].mean()

best_weights = model.get_weights()
np.save("weights/" + model_name, best_weights, allow_pickle=True)
# Out:
# Started training model.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-10
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-7.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# Train on 3636 samples, validate on 404 samples
# Epoch 1/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9948 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9948
# Epoch 00001: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 39s 11ms/sample - loss: -0.9949 - metric_VAMP: 0.9974 - metric_VAMP2: 0.9949 - val_loss: -0.9974 - val_metric_VAMP: 0.9987 - val_metric_VAMP2: 0.9974
# Epoch 2/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9944 - metric_VAMP: 0.9972 - metric_VAMP2: 0.9944
# Epoch 00002: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9944 - metric_VAMP: 0.9972 - metric_VAMP2: 0.9944 - val_loss: -0.9984 - val_metric_VAMP: 0.9992 - val_metric_VAMP2: 0.9984
# Epoch 3/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9972 - metric_VAMP: 0.9986 - metric_VAMP2: 0.9972
# Epoch 00003: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9972 - metric_VAMP: 0.9986 - metric_VAMP2: 0.9972 - val_loss: -0.9970 - val_metric_VAMP: 0.9986 - val_metric_VAMP2: 0.9971
# Epoch 4/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9957 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9957
# Epoch 00004: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9957 - metric_VAMP: 0.9978 - metric_VAMP2: 0.9956 - val_loss: -0.9985 - val_metric_VAMP: 0.9993 - val_metric_VAMP2: 0.9985
# Epoch 5/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9977 - metric_VAMP: 0.9989 - metric_VAMP2: 0.9977
# Epoch 00005: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 36s 10ms/sample - loss: -0.9977 - metric_VAMP: 0.9988 - metric_VAMP2: 0.9977 - val_loss: -0.9989 - val_metric_VAMP: 0.9994 - val_metric_VAMP2: 0.9989
# Epoch 6/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9972 - metric_VAMP: 0.9986 - metric_VAMP2: 0.9972
# Epoch 00006: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 37s 10ms/sample - loss: -0.9972 - metric_VAMP: 0.9986 - metric_VAMP2: 0.9972 - val_loss: -0.9986 - val_metric_VAMP: 0.9993 - val_metric_VAMP2: 0.9985
# Epoch 7/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9983 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9983
# Epoch 00007: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 36s 10ms/sample - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9984 - val_loss: -0.9990 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9990
# Epoch 8/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9981 - metric_VAMP: 0.9991 - metric_VAMP2: 0.9981
# Epoch 00008: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9982 - metric_VAMP: 0.9991 - metric_VAMP2: 0.9982 - val_loss: -0.9985 - val_metric_VAMP: 0.9993 - val_metric_VAMP2: 0.9985
# Epoch 9/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9983
# Epoch 00009: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9983 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9983 - val_loss: -0.9984 - val_metric_VAMP: 0.9992 - val_metric_VAMP2: 0.9984
# Epoch 10/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9976 - metric_VAMP: 0.9988 - metric_VAMP2: 0.9976
# Epoch 00010: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9975 - metric_VAMP: 0.9988 - metric_VAMP2: 0.9975 - val_loss: -0.9990 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9990
# Epoch 11/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9976 - metric_VAMP: 0.9988 - metric_VAMP2: 0.9976
# Epoch 00011: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9976 - metric_VAMP: 0.9988 - metric_VAMP2: 0.9976 - val_loss: -0.9988 - val_metric_VAMP: 0.9994 - val_metric_VAMP2: 0.9989
# Epoch 12/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9984
# Epoch 00012: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9984 - val_loss: -0.9986 - val_metric_VAMP: 0.9993 - val_metric_VAMP2: 0.9986
# Epoch 13/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9985 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9985
# Epoch 00013: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 34s 9ms/sample - loss: -0.9985 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9985 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 14/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9984
# Epoch 00014: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 34s 9ms/sample - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9984 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 15/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9987
# Epoch 00015: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9987 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9987 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 16/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9985 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9985
# Epoch 00016: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9985 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9985 - val_loss: -0.9987 - val_metric_VAMP: 0.9994 - val_metric_VAMP2: 0.9987
# Epoch 17/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987
# Epoch 00017: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 18/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9986 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9986
# Epoch 00018: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 37s 10ms/sample - loss: -0.9986 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9986 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 19/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9987
# Epoch 00019: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 37s 10ms/sample - loss: -0.9987 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9987 - val_loss: -0.9988 - val_metric_VAMP: 0.9994 - val_metric_VAMP2: 0.9988
# Epoch 20/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9984
# Epoch 00020: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 38s 10ms/sample - loss: -0.9984 - metric_VAMP: 0.9992 - metric_VAMP2: 0.9984 - val_loss: -0.9988 - val_metric_VAMP: 0.9994 - val_metric_VAMP2: 0.9988
# Epoch 21/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987
# Epoch 00021: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987 - val_loss: -0.9989 - val_metric_VAMP: 0.9994 - val_metric_VAMP2: 0.9989
# Epoch 22/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9986 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9986
# Epoch 00022: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9986 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9986 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 23/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00023: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 24/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9987
# Epoch 00024: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9987 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9987 - val_loss: -0.9989 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9990
# Epoch 25/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00025: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 26/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987
# Epoch 00026: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987 - val_loss: -0.9988 - val_metric_VAMP: 0.9993 - val_metric_VAMP2: 0.9987
# Epoch 27/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9986 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9986
# Epoch 00027: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9986 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9986 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 28/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00028: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9990 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9990
# Epoch 29/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9985 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9985
# Epoch 00029: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9985 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9985 - val_loss: -0.9990 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9991
# Epoch 30/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00030: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9990 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9989
# Epoch 31/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989
# Epoch 00031: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 32/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00032: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 33/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00033: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 36s 10ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 34/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989
# Epoch 00034: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 41s 11ms/sample - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989 - val_loss: -0.9991 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9991
# Epoch 35/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00035: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 36/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00036: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 35s 10ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9991 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9991
# Epoch 37/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987
# Epoch 00037: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 38/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00038: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9988 - val_metric_VAMP: 0.9994 - val_metric_VAMP2: 0.9988
# Epoch 39/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00039: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9991 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9991
# Epoch 40/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00040: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 39s 11ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 41/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9990 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9990
# Epoch 00041: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9990 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9990 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 42/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00042: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 34s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9990 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9990
# Epoch 43/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989
# Epoch 00043: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 44/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00044: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 45/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00045: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 46/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00046: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 35s 10ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 47/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00047: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 48/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00048: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 34s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9987 - val_metric_VAMP: 0.9993 - val_metric_VAMP2: 0.9987
# Epoch 49/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9987 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9987
# Epoch 00049: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9987 - metric_VAMP: 0.9993 - metric_VAMP2: 0.9987 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 50/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00050: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 51/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988
# Epoch 00051: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9988 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9988 - val_loss: -0.9991 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9991
# Epoch 52/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989
# Epoch 00052: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 40s 11ms/sample - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 53/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00053: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 54/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00054: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 40s 11ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 55/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00055: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9990 - val_metric_VAMP: 0.9995 - val_metric_VAMP2: 0.9990
# Epoch 56/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00056: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 57/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9990 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9990
# Epoch 00057: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 36s 10ms/sample - loss: -0.9990 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9990 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 58/100
# 3616/3636 [============================>.] - ETA: 0s - loss: -0.9989 - metric_VAMP: 0.9994 - metric_VAMP2: 0.9989
# Epoch 00058: saving model to model_checkpoints/
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x7ff54022cc50>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 3636/3636 [==============================] - 33s 9ms/sample - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989 - val_loss: -0.9992 - val_metric_VAMP: 0.9996 - val_metric_VAMP2: 0.9992
# Epoch 59/100
#  960/3636 [======>.......................] - ETA: 23s - loss: -0.9989 - metric_VAMP: 0.9995 - metric_VAMP2: 0.9989
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_105610/3206672664.py in <module>
#      93                      epochs=nb_epoch,
#      94                      validation_data=([X1_vali, X2_vali], Y_vali ),
# ---> 95                      verbose=1, callbacks=my_callbacks)
#      96
#      97
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# ~/miniconda3/envs/tfenv/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# SAVE MODEL WEIGHTS

best_weights = model.get_weights()
np.save("weights/" + model_name, best_weights, allow_pickle=True)
# Out:
# /uni-mainz.de/homes/tuchkovy/miniconda3/envs/tfenv/lib/python3.7/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %% [markdown]
# # Training result visualization

# %%
# Transform the input trajectory using the network
states_prob = model.predict([traj_ord, traj_ord_lag])[:, :output_size]

# Order the output states based on their population
coor_pred = np.argmax(states_prob, axis = 1)
indexes = [np.where(coor_pred == np.multiply(np.ones_like(coor_pred), n)) for n in range(output_size)]
states_num = [len(i[0]) for i in indexes]
states_order = np.argsort(states_num).astype('int')[::-1]

pred_ord = states_prob[:,states_order]
pred_ord = np.round(pred_ord, decimals = 3)
# Out:
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103022 thread 1 bound to OS proc set 1
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103023 thread 2 bound to OS proc set 2
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103025 thread 3 bound to OS proc set 3
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103026 thread 4 bound to OS proc set 4
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103028 thread 6 bound to OS proc set 6
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103027 thread 5 bound to OS proc set 5
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103030 thread 8 bound to OS proc set 0
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103029 thread 7 bound to OS proc set 7
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103031 thread 9 bound to OS proc set 1
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103033 thread 11 bound to OS proc set 3
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103032 thread 10 bound to OS proc set 2
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103035 thread 13 bound to OS proc set 5
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103034 thread 12 bound to OS proc set 4
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103036 thread 14 bound to OS proc set 6
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103037 thread 15 bound to OS proc set 7
# OMP: Info #250: KMP_AFFINITY: pid 102794 tid 103038 thread 16 bound to OS proc set 0

# %% [markdown]
# # Visualize the population of the states

# %%
tau_msm = 35

def print_states_pie_chart():
    coors = []
    maxi = np.max(pred_ord, axis= 1)

    for i in range(output_size):
        coors.append(len(np.where(pred_ord[:,i] == maxi)[0]))
        
    fig1, ax1 = plt.subplots()
    ax1.pie(np.array(coors), autopct='%1.2f%%', startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    print(model_name + '   States population: '+str(np.array(coors)/len(maxi)*100)+'%')
    plt.show()
    plt.savefig("states_population.png")

print_states_pie_chart()

#note: the matrix is row stochastic.
#A markov chain transition will correspond to left multiplying by a row vector.
K_smt_nonmeanfree = vamp.estimate_koopman_op(pred_ord, tau_msm)
Q = K_smt_nonmeanfree

#We have to transpose so that Markov transitions correspond to right multiplying by a column vector.  np.linalg.eig finds right eigenvectors.
evals, evecs = np.linalg.eig(Q.T)
evec1 = evecs[:,np.isclose(evals, 1)]

#Since np.isclose will return an array, we've indexed with an array
#so we still have our 2nd axis.  Get rid of it, since it's only size 1.
evec1 = evec1[:,0]

stationary = evec1 / evec1.sum()

#eigs finds complex eigenvalues and eigenvectors, so you'll want the real part.
stationary = stationary.real

print(model_name + "   Stable vector: ", stationary * 100, "%");
# Out:
# 2_states_E10_peptides_input_   States population: [68.67291564 31.40108535]%
# 2_states_E10_peptides_input_   Stable vector:  [64.01532 35.98468] %

# %%
# %load_ext autoreload
# %autoreload 2

tau_msm = 5

K_smt_nonmeanfree = vamp.estimate_koopman_op(pred_ord, tau_msm)
K_smt_nonmeanfree = np.round(K_smt_nonmeanfree, decimals = 3)
import numpy as np
import matplotlib.pyplot as plt 
# Import the MarkovChain class from markovchain.py
from markovchain import MarkovChain


nodes_facecolor = ['#377eb8', '#ff7f00']
mc = MarkovChain(K_smt_nonmeanfree, ['1', '2'], nodes_facecolor = nodes_facecolor)
mc.draw()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Markov Model Estimation

# %% [markdown]
# # Estimate the implied timescales

# %%
max_tau = 200
lag = np.arange(1, max_tau, 1)
its = vamp.get_its(pred_ord, lag)
vamp.plot_its(its, lag)

# %% [markdown]
# # Chapman-Kolmogorov test for the estimated koopman operator

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

def custom_plot_ck_test(pred, est, n_states, steps, tau):
        '''Plots the result of the Chapman-Kolmogorov test calculated by the function
        'get_ck_test'
        Parameters
        ----------
        pred: numpy array
        est: numpy array
            pred, est are the two arrays returned by the function get_ck_test
        n_states: int
        steps: int
        tau: int
            values used for the Chapman-Kolmogorov test as parameters in the function
            get_ck_test
        '''
        
        fig, ax = plt.subplots(n_states, n_states, sharex=True, sharey=True)
        for index_i in range(n_states):
            for index_j in range(n_states):
                
                ax[index_i][index_j].plot(np.arange(0, steps*tau, tau) * picoseconds_per_step
                                          ,pred[index_i, index_j], color='b')
                
                ax[index_i][index_j].plot(np.arange(0, steps*tau, tau) * picoseconds_per_step
                                          ,est[index_i, index_j], color='r', linestyle='--')
                
                ax[index_i][index_j].set_title(str(index_i+1)+ '->' +str(index_j+1),
                                               fontsize='small')
        
        ax[0][0].set_ylim((-0.1,1.1));
        ax[0][0].set_xlim((0, steps*tau));
        
        ax[0][0].axes.get_xaxis().set_ticks(np.round(np.linspace(0, steps*tau, 5)) * picoseconds_per_step);#(np.round(np.linspace(0, steps*tau, 5)));
        #ax[0][0].axes.get_xaxis().set_ticks(np.round(np.linspace(0, steps*tau, 5)));
        
        
        # -------------------------------------------
        
        
        ax[1][1].axes.set_xlabel("Time lag, ps")
        ax[1][0].axes.set_xlabel("Time lag, ps")
        
        #ax[1][1].axes.set_xlabel("time lag, steps")
        #ax[1][1].axes.set_xlabel("time lag, steps")
        
        '''ax2 = ax[0][0].twiny()
        ax2.set_xlabel("x-transformed")
        ax2.set_xlim(0, 60)'''
        #ax2.set_xticks(np.arange(0, steps*tau, tau) * picoseconds_per_step)
        
        plt.show()
        

steps = 2**9 #2**4 or 2**9
predicted, estimated = vamp.get_ck_test(pred_ord, steps, tau_msm)
custom_plot_ck_test(predicted, estimated, output_size, steps, tau_msm)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

y = np.arange(0, steps*tau_msm, tau_msm)
x = [np.arange(0, steps*tau_msm, tau_msm), np.arange(0, steps*tau_msm, tau_msm) * picoseconds_per_step]
labels = ['m/s', 'km/hr']

fig = plt.figure()
# generate the first axis
ax = host_subplot(111, axes_class = AA.Axes, figure = fig)
ax.plot(x[0], y)
ax.set_xlabel("Time lag, steps")
ax.set_ylabel("Time /mins")

ax2=ax.twiny()

# make space for the secondary axis
plt.subplots_adjust(bottom = 0.2)

# set position ax2 axis
offset = -40
new_fixed_axis = ax2.get_grid_helper().new_fixed_axis
ax2.axis['bottom'] = new_fixed_axis(loc = 'bottom',
                                    axes = ax2,
                                    offset = (0, offset))
ax2.axis['bottom'].toggle(all = True)

ax2.plot(x[1], y)
ax2.set_xlabel("Time lag, ps")
plt.show()

# %% [markdown]
# ## Make probabilites distribution live animation

# %%
import matplotlib.pyplot as plt
from matplotlib import animation

plt.style.use("seaborn-dark")
test_snapshots = 500
state_probability = x_a[:test_snapshots,:]

def barlist(n): 
    return [1/float(n*k) for k in range(1,3)]

fig=plt.figure()

n=test_snapshots #Number of frames
x=range(2)
barcollection = plt.bar(x,barlist(1))
barcollection[0].set_color('r')
barcollection[1].set_color('b')

tick_lst = ["Bound", "Non-Bound"]

def animate(frame):
    y=[state_probability[frame, 0], state_probability[frame, 1]]
    for i, b in enumerate(barcollection):
        b.set_height(y[i])
        plt.xticks(np.arange(2), tick_lst)
        plt.title("Frame: " + str(frame), color=("blue"))

anim=animation.FuncAnimation(fig,animate,repeat=False,blit=False,frames=n,
                             interval=100)

anim.save('E10_coords365K_75_1_0__997150__9.mp4',writer=animation.FFMpegWriter(fps=13.4))
plt.show()
# Out:
# 16
